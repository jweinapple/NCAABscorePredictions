# %% [markdown]
# # Model Validation and Visuals

# %% [markdown]
# Import required libraries

# %%
import pandas as pd
import seaborn as sns
import numpy as np
from plotnine import *

#gives ability to see all columns in a given dataframe
pd.set_option('display.max_columns', None)

# %% [markdown]
# Read in CleanedTeamData and gamedataXGBoostgridpredictionsallpca csvs

# %%
team = pd.read_csv("~/jupyter/capstone_Group10/data/CleanedTeamData.csv")
game = pd.read_csv("~/jupyter/capstone_Group10/data/gamedataXGBoostgridpredictionsallpca2020.csv")
game.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21817 entries, 0 to 21816
# Columns: 122 entries, gamedatekey to margin
# dtypes: float64(110), int64(2), object(10)
# memory usage: 20.3+ MB

# %%
game.head()
# Out:
#                      gamedatekey  season       date  \
# 0             2016-11-11-alabama    2017  11-Nov-16
# 1  2016-11-11-alabama-birmingham    2017  11-Nov-16
# 2       2016-11-11-arizona-state    2017  11-Nov-16
# 3            2016-11-11-arkansas    2017  11-Nov-16
# 4              2016-11-11-auburn    2017  11-Nov-16
#
#                                    location winner             awayteam  \
# 0    Coleman Coliseum , Tuscaloosa, Alabama   Home     COASTAL_CAROLINA
# 1         Bartow Arena, Birmingham, Alabama   Home  ARKANSAS_PINE_BLUFF
# 2         Wells Fargo Arena, Tempe, Arizona   Home       PORTLAND_STATE
# 3  Bud Walton Arena, Fayetteville, Arkansas   Home                 IPFW
# 4             Auburn Arena, Auburn, Alabama   Home        NORTH_FLORIDA
#
#              hometeam  home_points  away_points home_teamname_season  \
# 0             ALABAMA         70.0         53.0         ALABAMA_2017
# 1  ALABAMA_BIRMINGHAM         86.0         66.0             UAB_2017
# 2       ARIZONA_STATE         88.0         70.0   ARIZONA_STATE_2017
# 3            ARKANSAS         92.0         83.0        ARKANSAS_2017
# 4              AUBURN         83.0         66.0          AUBURN_2017
#
#        away_teamname_season  hometeam_adjem  hometeam_adj_o  hometeam_adj_d  \
# 0     COASTAL_CAROLINA_2017           13.08           105.3            92.2
# 1  ARKANSAS_PINE_BLUFF_2017           -2.52           103.9           106.4
# 2       PORTLAND_STATE_2017            2.81           111.9           109.1
# 3    PURDUE_FORT_WAYNE_2017           16.25           116.1            99.8
# 4        NORTH_FLORIDA_2017            8.52           111.9           103.3
#
#    hometeam_adj_t  hometeam_luck  hometeam_sos_adj_em  hometeam_sos_oppo  \
# 0            65.1         -0.055                 7.16              108.1
# 1            66.1         -0.008                -2.45              103.6
# 2            70.0          0.035                 6.49              108.6
# 3            69.7          0.086                 8.37              108.6
# 4            73.6          0.045                 6.99              107.5
#
#    hometeam_sos_oppd  hometeam_ncsos_adj  hometeam_assist_percentage  \
# 0              100.9               -1.64                        48.2
# 1              106.0                0.08                        60.2
# 2              102.1               -1.06                        48.4
# 3              100.2               -1.55                        49.8
# 4              100.5                1.35                        48.3
#
#    hometeam_away_losses  hometeam_away_wins  hometeam_block_percentage  \
# 0                   6.0                 5.0                       11.6
# 1                   8.0                 4.0                       13.2
# 2                   6.0                 4.0                        8.8
# 3                   5.0                 6.0                       12.4
# 4                   6.0                 6.0                       13.4
#
#   hometeam_conference  hometeam_conference_losses  hometeam_conference_wins  \
# 0                 sec                         8.0                      10.0
# 1                cusa                         9.0                       9.0
# 2              pac-12                        11.0                       7.0
# 3                 sec                         6.0                      12.0
# 4                 sec                        11.0                       7.0
#
#    hometeam_effective_field_goal_percentage  hometeam_field_goal_percentage  \
# 0                                     0.483                           0.424
# 1                                     0.518                           0.462
# 2                                     0.514                           0.434
# 3                                     0.514                           0.461
# 4                                     0.511                           0.437
#
#    hometeam_free_throw_attempt_rate  hometeam_free_throw_percentage  \
# 0                             0.391                           0.653
# 1                             0.373                           0.736
# 2                             0.319                           0.749
# 3                             0.381                           0.761
# 4                             0.425                           0.672
#
#    hometeam_free_throws_per_field_goal_attempt  hometeam_home_losses  \
# 0                                        0.255                   6.0
# 1                                        0.274                   5.0
# 2                                        0.239                   7.0
# 3                                        0.290                   3.0
# 4                                        0.285                   5.0
#
#    hometeam_home_wins  hometeam_total_losses  hometeam_net_rating  \
# 0                11.0                   15.0                  5.6
# 1                11.0                   16.0                  2.3
# 2                 9.0                   18.0                 -4.2
# 3                15.0                   10.0                  7.6
# 4                10.0                   14.0                  1.1
#
#    hometeam_offensive_rating  hometeam_offensive_rebound_percentage  \
# 0                      100.3                                   34.1
# 1                      105.1                                   30.2
# 2                      108.0                                   24.4
# 3                      110.7                                   31.7
# 4                      106.1                                   30.3
#
#    hometeam_opp_assist_percentage  hometeam_opp_block_percentage  \
# 0                            43.4                            8.3
# 1                            50.2                            8.2
# 2                            63.5                           11.3
# 3                            50.4                            7.7
# 4                            50.5                            7.9
#
#    hometeam_opp_effective_field_goal_percentage  \
# 0                                         0.461
# 1                                         0.495
# 2                                         0.554
# 3                                         0.478
# 4                                         0.506
#
#    hometeam_opp_field_goal_percentage  hometeam_opp_free_throw_attempt_rate  \
# 0                               0.405                                 0.399
# 1                               0.431                                 0.293
# 2                               0.479                                 0.300
# 3                               0.417                                 0.390
# 4                               0.437                                 0.388
#
#    hometeam_opp_free_throw_percentage  \
# 0                               0.671
# 1                               0.692
# 2                               0.712
# 3                               0.705
# 4                               0.720
#
#    hometeam_opp_free_throws_per_field_goal_attempt  \
# 0                                            0.268
# 1                                            0.203
# 2                                            0.213
# 3                                            0.275
# 4                                            0.279
#
#    hometeam_opp_offensive_rating  hometeam_opp_offensive_rebound_percentage  \
# 0                           94.7                                       26.6
# 1                          102.8                                       28.1
# 2                          112.2                                       32.2
# 3                          103.1                                       33.9
# 4                          105.0                                       33.2
#
#    hometeam_opp_steal_percentage  hometeam_opp_three_point_attempt_rate  \
# 0                            9.3                                  0.340
# 1                            9.7                                  0.377
# 2                            7.1                                  0.409
# 3                            7.2                                  0.367
# 4                            8.1                                  0.388
#
#    hometeam_opp_three_point_field_goal_percentage  \
# 0                                           0.333
# 1                                           0.342
# 2                                           0.364
# 3                                           0.332
# 4                                           0.357
#
#    hometeam_opp_total_rebound_percentage  \
# 0                                   46.2
# 1                                   47.6
# 2                                   54.9
# 3                                   50.5
# 4                                   51.6
#
#    hometeam_opp_true_shooting_percentage  hometeam_opp_turnover_percentage  \
# 0                                  0.500                              17.3
# 1                                  0.524                              14.7
# 2                                  0.578                              15.9
# 3                                  0.519                              15.7
# 4                                  0.545                              17.1
#
#    hometeam_opp_two_point_field_goal_percentage  hometeam_pace  \
# 0                                         0.442           67.4
# 1                                         0.484           67.8
# 2                                         0.559           72.5
# 3                                         0.467           71.7
# 4                                         0.487           75.2
#
#    hometeam_simple_rating_system  hometeam_steal_percentage  \
# 0                          11.29                        8.6
# 1                          -1.17                        7.0
# 2                           4.02                        8.1
# 3                          14.04                       10.8
# 4                           8.17                        9.6
#
#    hometeam_strength_of_schedule  hometeam_three_point_attempt_rate  \
# 0                           7.47                              0.372
# 1                          -1.83                              0.322
# 2                           7.11                              0.438
# 3                           8.60                              0.295
# 4                           7.33                              0.401
#
#    hometeam_two_point_field_goal_percentage  hometeam_win_percentage  \
# 0                                     0.487                    0.559
# 1                                     0.515                    0.515
# 2                                     0.487                    0.455
# 3                                     0.500                    0.722
# 4                                     0.485                    0.563
#
#    hometeam_total_wins  awayteam_adjem  awayteam_adj_o  awayteam_adj_d  \
# 0                 19.0           -3.56           101.8           105.4
# 1                 17.0          -25.28            85.7           111.0
# 2                 15.0           -6.50           104.3           110.8
# 3                 26.0            0.84           108.8           108.0
# 4                 18.0           -7.64           101.8           109.5
#
#    awayteam_adj_t  awayteam_luck  awayteam_sos_adj_em  awayteam_sos_oppo  \
# 0            68.8          0.050                -1.39              103.8
# 1            67.6         -0.010                -9.35              100.4
# 2            72.6         -0.057                -6.52              101.9
# 3            71.6         -0.025                -3.36              105.4
# 4            69.9          0.025                -0.46              105.9
#
#    awayteam_sos_oppd  awayteam_ncsos_adj  awayteam_assist_percentage  \
# 0              105.2                1.16                        45.7
# 1              109.7                2.79                        48.1
# 2              108.5               -0.17                        51.2
# 3              108.7               -4.33                        54.6
# 4              106.4                6.82                        48.3
#
#    awayteam_away_losses  awayteam_away_wins  awayteam_block_percentage  \
# 0                  12.0                 3.0                        8.7
# 1                  19.0                 1.0                        9.5
# 2                  12.0                 4.0                        7.2
# 3                   9.0                 6.0                       11.0
# 4                  13.0                 4.0                       10.0
#
#   awayteam_conference  awayteam_conference_losses  awayteam_conference_wins  \
# 0            sun-belt                         8.0                      10.0
# 1                swac                        12.0                       6.0
# 2             big-sky                        11.0                       7.0
# 3              summit                         8.0                       8.0
# 4        atlantic-sun                         6.0                       8.0
#
#    awayteam_effective_field_goal_percentage  awayteam_field_goal_percentage  \
# 0                                     0.488                           0.423
# 1                                     0.463                           0.403
# 2                                     0.541                           0.482
# 3                                     0.579                           0.496
# 4                                     0.530                           0.457
#
#    awayteam_free_throw_attempt_rate  awayteam_free_throw_percentage  \
# 0                             0.298                           0.658
# 1                             0.337                           0.652
# 2                             0.373                           0.658
# 3                             0.264                           0.725
# 4                             0.369                           0.655
#
#    awayteam_free_throws_per_field_goal_attempt  awayteam_home_losses  \
# 0                                        0.196                   6.0
# 1                                        0.220                   6.0
# 2                                        0.246                   3.0
# 3                                        0.191                   3.0
# 4                                        0.242                   5.0
#
#    awayteam_home_wins  awayteam_total_losses  awayteam_net_rating  \
# 0                15.0                   19.0                 -0.8
# 1                 6.0                   25.0                -15.3
# 2                10.0                   16.0                  4.6
# 3                14.0                   13.0                 10.6
# 4                10.0                   19.0                 -1.5
#
#    awayteam_offensive_rating  awayteam_offensive_rebound_percentage  \
# 0                      101.7                                   31.0
# 1                       88.2                                   29.8
# 2                      110.8                                   27.5
# 3                      114.0                                   29.1
# 4                      105.8                                   34.2
#
#    awayteam_opp_assist_percentage  awayteam_opp_block_percentage  \
# 0                            52.3                            9.0
# 1                            59.1                            8.4
# 2                            56.7                            6.6
# 3                            54.4                            6.6
# 4                            53.2                            9.5
#
#    awayteam_opp_effective_field_goal_percentage  \
# 0                                         0.496
# 1                                         0.512
# 2                                         0.554
# 3                                         0.524
# 4                                         0.508
#
#    awayteam_opp_field_goal_percentage  awayteam_opp_free_throw_attempt_rate  \
# 0                               0.417                                 0.320
# 1                               0.448                                 0.564
# 2                               0.481                                 0.337
# 3                               0.443                                 0.313
# 4                               0.448                                 0.338
#
#    awayteam_opp_free_throw_percentage  \
# 0                               0.707
# 1                               0.708
# 2                               0.726
# 3                               0.747
# 4                               0.686
#
#    awayteam_opp_free_throws_per_field_goal_attempt  \
# 0                                            0.226
# 1                                            0.399
# 2                                            0.245
# 3                                            0.234
# 4                                            0.232
#
#    awayteam_opp_offensive_rating  awayteam_opp_offensive_rebound_percentage  \
# 0                          102.5                                       26.1
# 1                          103.5                                       34.9
# 2                          106.2                                       30.3
# 3                          103.4                                       23.3
# 4                          107.3                                       31.3
#
#    awayteam_opp_steal_percentage  awayteam_opp_three_point_attempt_rate  \
# 0                            8.3                                  0.468
# 1                           13.6                                  0.399
# 2                            7.7                                  0.399
# 3                            8.3                                  0.420
# 4                           11.0                                  0.335
#
#    awayteam_opp_three_point_field_goal_percentage  \
# 0                                           0.336
# 1                                           0.318
# 2                                           0.369
# 3                                           0.383
# 4                                           0.358
#
#    awayteam_opp_total_rebound_percentage  \
# 0                                   48.0
# 1                                   53.2
# 2                                   52.4
# 3                                   46.7
# 4                                   48.1
#
#    awayteam_opp_true_shooting_percentage  awayteam_opp_turnover_percentage  \
# 0                                  0.529                              14.8
# 1                                  0.561                              20.6
# 2                                  0.583                              19.5
# 3                                  0.558                              16.7
# 4                                  0.538                              14.1
#
#    awayteam_opp_two_point_field_goal_percentage  awayteam_pace  \
# 0                                         0.489           71.0
# 1                                         0.535           68.7
# 2                                         0.554           74.6
# 3                                         0.487           75.1
# 4                                         0.493           73.3
#
#    awayteam_simple_rating_system  awayteam_steal_percentage  \
# 0                          -3.94                        8.5
# 1                         -22.81                       12.4
# 2                          -7.06                       12.9
# 3                           0.38                       10.1
# 4                          -7.78                        7.4
#
#    awayteam_strength_of_schedule  awayteam_three_point_attempt_rate  \
# 0                          -1.48                              0.399
# 1                         -10.28                              0.360
# 2                          -6.63                              0.350
# 3                          -3.19                              0.412
# 4                          -1.65                              0.415
#
#    awayteam_two_point_field_goal_percentage  awayteam_win_percentage  \
# 0                                     0.484                    0.513
# 1                                     0.441                    0.219
# 2                                     0.557                    0.484
# 3                                     0.562                    0.606
# 4                                     0.533                    0.441
#
#    awayteam_total_wins  hometeam_dist  awayteam_dist  hometeam_seasonelo  \
# 0                 20.0            0.0     792.896553         1541.968340
# 1                  7.0            0.0     488.414514                 NaN
# 2                 15.0            0.0    1627.283096         1449.795309
# 3                 20.0            0.0     966.121812         1624.573878
# 4                 15.0            0.0     458.181115         1580.807752
#
#    awayteam_seasonelo  neutral  home_points_pred  away_points_pred  \
# 0         1483.221051      0.0         73.906261                59
# 1         1429.443195      0.0         76.284936                54
# 2         1477.023198      0.0         89.869958                81
# 3                 NaN      0.0         89.309799                77
# 4         1448.327706      0.0         91.360923                75
#
#    pred_margin  margin
# 0    14.906261    17.0
# 1    22.284936    20.0
# 2     8.869958    18.0
# 3    12.309799     9.0
# 4    16.360923    17.0

# %% [markdown]
# ## Visuals - Predicted Margin

# %% [markdown]
# Below we can see a left skewed plot of the predicted margin variable in the game dataframe. As we can see, most of the predicted margins are below 10 points, with the median around 4.5-5 points.

# %%
sns.distplot(game['pred_margin'])

# %% [markdown]
# Below we can see another left skewed plot with the actual margin of games. The median of actual margins is around the same as the predict plots

# %%
sns.distplot(game['margin'])

# %% [markdown]
# ## Visuals - Home Points

# %% [markdown]
# We now see the plot of actual and predicted points scored by the home team to have a normal distribution with a median around 75 points.

# %%
sns.distplot(game['home_points'])

# %%
sns.distplot(game['home_points_pred'])

# %% [markdown]
# ## Visuals - Away Points

# %% [markdown]
# We now see the plot of actual and predicted points scored by the away team to have a normal distribution with a median around 68 points.

# %%
sns.distplot(game['away_points'])

# %%
sns.distplot(game['away_points_pred'])

# %% [markdown]
# ## Creating Bins for Actual vs. Predicted Scores

# %% [markdown]
# We now would like to check whether the difference (margin) between actual home points and predicted home points scored during a given game is within 10 points

# %%
hcheck = [] 
for i,r in game.iterrows():
    act = r['home_points'] 
    pred =  round(r['home_points_pred'],0)
    if(abs(act-pred) <= 10):
        hcheck.append('yes')
    else: 
        hcheck.append('no')
game['homeWithin10'] =hcheck
game['homeWithin10'] = game['homeWithin10'].astype('category')

# %% [markdown]
# The following bins the difference (margin) between actual home points and predicted home points scored during a given game in the following buckets:
#
# - Zero
# - Less Than 5
# - Between 5-10
# - Between 10-15
# - Between 15-20
# - More than 20

# %%
check = [] 
for i,r in game.iterrows():
    act = r['home_points'] 
    pred =  round(r['home_points_pred'],0)
    if(act-pred == 0):
         check.append('Zero')
    elif((abs(act-pred) <= 5) and  (abs(act-pred) > 0)):
        check.append('Less Than 5')
    elif((abs(act-pred) <= 10 ) and  (abs(act-pred) >= 5)):
        check.append('Between 5-10')
    elif((abs(act-pred) <= 15) and (abs(act-pred) >= 10)):
        check.append('Between 10-15')
    elif((abs(act-pred) <= 20 ) and  (abs(act-pred) >= 15)):
        check.append('Between 15-20')
    else: 
        check.append('More than 20')
game['home_Actual_vs_Predicted_scores_Margin'] =check
game['home_Actual_vs_Predicted_scores_Margin'] = game['home_Actual_vs_Predicted_scores_Margin'].astype('category')
game['home_Actual_vs_Predicted_scores_Margin'].cat.reorder_categories(['Zero', 'Less Than 5', 'Between 5-10', 'Between 10-15', 'Between 15-20','More than 20'],inplace=True)

# %% [markdown]
# We now would like to check whether the difference (margin) between actual away points and predicted away points scored during a given game is within 10 points

# %%
acheck = [] 
for i,r in game.iterrows():
    act = r['away_points'] 
    pred =  round(r['away_points_pred'],0)
    if(abs(act-pred) <= 10):
        acheck.append(1)
    else: 
        acheck.append(0)
game['awayWithin10'] =acheck
game['awayWithin10'] = game['awayWithin10'].astype('category')

# %% [markdown]
# The following bins the difference (margin) between actual away points and predicted away points scored during a given game in the following buckets:
#
# - Zero
# - Less Than 5
# - Between 5-10
# - Between 10-15
# - Between 15-20
# - More than 20

# %%
check = [] 
for i,r in game.iterrows():
    act = r['away_points'] 
    pred =  round(r['away_points_pred'],0)
    if(act-pred == 0 ):
         check.append('Zero')
    elif((abs(act-pred) <= 5) and  (abs(act-pred) > 0)):
        check.append('Less Than 5')
    elif((abs(act-pred) <= 10 ) and  (abs(act-pred) >= 5)):
        check.append('Between 5-10')
    elif((abs(act-pred) <= 15) and (abs(act-pred) >= 10)):
        check.append('Between 10-15')
    elif((abs(act-pred) <= 20 ) and  (abs(act-pred) >= 15)):
        check.append('Between 15-20')
    else: 
        check.append('More than 20')
game['away_Actual_vs_Predicted_scores_Margin'] =check
game['away_Actual_vs_Predicted_scores_Margin'] = game['away_Actual_vs_Predicted_scores_Margin'].astype('category')
game['away_Actual_vs_Predicted_scores_Margin'].cat.reorder_categories(['Zero', 'Less Than 5', 'Between 5-10', 'Between 10-15', 'Between 15-20','More than 20'],inplace=True)

# %% [markdown]
# ### Plotting Actual vs. Predicted

# %% [markdown]
# #### Home plot

# %% [markdown]
# Per the plot below you can see the buckets placed in a colored scatterplot. You will see that pink values through the middle of the plot is where the actual vs predicted is spot on for the model. As the margin grows, the color of the points start to darken

# %%
a = (ggplot(game) + 
    geom_point(aes(x= "home_points", y="home_points_pred",fill='home_Actual_vs_Predicted_scores_Margin',color='home_Actual_vs_Predicted_scores_Margin')) + labs(x="Home Points Actual",y="Home Points Predicted",title="Home points vs Home Points Predicted", color = "Actual vs Predicted Margin Range", fill="Actual vs Predicted Margin Range")) + scale_color_brewer(palette="Blues")
a = a + scale_x_continuous(limits = (0,150)) +scale_y_continuous(limits = (0, 150)) 
#+  scale_fill_manual(values=("red", "yellow","orange","green","blue","purple"))

a = a + theme( panel_grid=element_line(color='grey'))

a
# Out:
# <ggplot: (-9223363284545943173)>

# %%
ggsave(plot=a, filename='Home Actual vs. Predicted Points.png', dpi=312,height=7, width=5, units = 'in')
# Out:
# /opt/conda/lib/python3.7/site-packages/plotnine/ggplot.py:729: PlotnineWarning: Saving 5 x 7 in image.
#   from_inches(height, units), units), PlotnineWarning)
# /opt/conda/lib/python3.7/site-packages/plotnine/ggplot.py:730: PlotnineWarning: Filename: Home Actual vs. Predicted Points.png
#   warn('Filename: {}'.format(filename), PlotnineWarning)

# %% [markdown]
# We can see which games had spot on predictions. Based on some inspection we can see the model predicted more points playing against worse teams which is expected. Also we see alot of the games with higher predictions occured in the 2016 and 2017 seasons.

# %%
new = game[game['home_Actual_vs_Predicted_scores_Margin'] == "Zero" ]
new[['date','hometeam','awayteam','home_points_pred','home_points']].sort_values('home_points',ascending=False).head(20)
# Out:
#             date          hometeam                  awayteam  \
# 39     11-Nov-16        IOWA_STATE            SAVANNAH_STATE
# 6526   28-Nov-17     WICHITA_STATE            SAVANNAH_STATE
# 16740   5-Nov-19           GONZAGA             ALABAMA_STATE
# 7489   22-Dec-17         VILLANOVA                   HOFSTRA
# 7385   20-Dec-17  NEVADA_LAS_VEGAS  MISSISSIPPI_VALLEY_STATE
# 5596   10-Nov-17          ARKANSAS                   SAMFORD
# 6934    9-Dec-17            BUTLER          YOUNGSTOWN_STATE
# 16115   6-Mar-19          MARSHALL     FLORIDA_INTERNATIONAL
# 21     11-Nov-16              DUKE                    MARIST
# 1134    3-Dec-16              DUKE                     MAINE
# 2682   12-Jan-17          LIPSCOMB                   STETSON
# 500    20-Nov-16          KENTUCKY                  DUQUESNE
# 5975   18-Nov-17           BELMONT           HOUSTON_BAPTIST
# 7055   10-Dec-17     VIRGINIA_TECH    MARYLAND_EASTERN_SHORE
# 11338  11-Nov-18              IOWA                 GREEN_BAY
# 13556   9-Jan-19            NEVADA            SAN_JOSE_STATE
# 5695   12-Nov-17              IOWA             ALABAMA_STATE
# 1420   10-Dec-16          ILLINOIS          CENTRAL_MICHIGAN
# 7334   19-Dec-17              IOWA             SOUTHERN_UTAH
# 14042  19-Jan-19           BELMONT           TENNESSEE_STATE
#
#        home_points_pred  home_points
# 39           112.754566        113.0
# 6526         111.854051        112.0
# 16740         94.861919         95.0
# 7489          95.396130         95.0
# 7385          95.222092         95.0
# 5596          95.078119         95.0
# 6934          94.602029         95.0
# 16115         93.850579         94.0
# 21            94.164144         94.0
# 1134          93.696050         94.0
# 2682          94.404286         94.0
# 500           93.383310         93.0
# 5975          92.751435         93.0
# 7055          92.826074         93.0
# 11338         92.851556         93.0
# 13556         91.802958         92.0
# 5695          92.322381         92.0
# 1420          92.195608         92.0
# 7334          92.195242         92.0
# 14042         91.835085         92.0

# %% [markdown]
# #### Away plot

# %%
a = (ggplot(game, aes(x= "away_points", y="away_points_pred",fill='away_Actual_vs_Predicted_scores_Margin',color='away_Actual_vs_Predicted_scores_Margin')) + 
    geom_point() + labs(title="Away points vs Away Points Predicted",fill='Actual vs Predicted Margin Range',color="Actual vs Predicted Margin Range"))
a = a + scale_x_continuous(limits = (0, 150)) +scale_y_continuous(limits = (0, 150)) 
a = a + scale_color_brewer(palette="Blues") + theme( panel_grid=element_line(color='grey')) +  labs(x="Away Points Actual",y="Away Points Predicted",title="Away points vs Away Points Predicted")
a
#+ scale_fill_manual(values=("red", "yellow","orange","green","blue","purple"))
# Out:
# <ggplot: (-9223363284562354723)>

# %%
ggsave(plot=a, filename='Away Actual vs. Predicted Points.png', dpi=312,height=7, width=5, units = 'in')
# Out:
# /opt/conda/lib/python3.7/site-packages/plotnine/ggplot.py:729: PlotnineWarning: Saving 5 x 7 in image.
#   from_inches(height, units), units), PlotnineWarning)
# /opt/conda/lib/python3.7/site-packages/plotnine/ggplot.py:730: PlotnineWarning: Filename: Away Actual vs. Predicted Points.png
#   warn('Filename: {}'.format(filename), PlotnineWarning)

# %% [markdown]
# We can see which away scores we predicted correctly. As noted before the predictions for away scores were lower than the Home model as only one of the correct predictions was greater than 90.

# %%
new = game[game['away_Actual_vs_Predicted_scores_Margin'] == "Zero" ]
new[['date','awayteam','hometeam','away_points_pred','away_points']].sort_values('away_points',ascending=False).head(20)
# Out:
#             date            awayteam                hometeam  \
# 10340  24-Feb-18      SAVANNAH_STATE         BETHUNE_COOKMAN
# 8218   11-Jan-18            MARSHALL               CHARLOTTE
# 2582   10-Jan-17               AKRON        CENTRAL_MICHIGAN
# 6073   19-Nov-17              AUBURN                 HOFSTRA
# 838    26-Nov-16    CENTRAL_MICHIGAN               GREEN_BAY
# 8508   17-Jan-18           VILLANOVA              GEORGETOWN
# 9689   10-Feb-18  FLORIDA_GULF_COAST  SOUTH_CAROLINA_UPSTATE
# 8126    8-Jan-18      SAVANNAH_STATE            MORGAN_STATE
# 3569   30-Jan-17      SAVANNAH_STATE  MARYLAND_EASTERN_SHORE
# 13123  29-Dec-18             BUFFALO                CANISIUS
# 14570  31-Jan-19  SOUTH_DAKOTA_STATE            ORAL_ROBERTS
# 7756   31-Dec-17    SAINT_FRANCIS_PA                  BRYANT
# 12027  26-Nov-18   TEXAS_SAN_ANTONIO         HOUSTON_BAPTIST
# 3526   28-Jan-17                DUKE             WAKE_FOREST
# 8106    7-Jan-18        WILLIAM_MARY                  DREXEL
# 8087    6-Jan-18             GONZAGA        LOYOLA_MARYMOUNT
# 9881   15-Feb-18        WILLIAM_MARY                 HOFSTRA
# 8629   19-Jan-18             BUFFALO        WESTERN_MICHIGAN
# 5951   17-Nov-17   NORTHERN_COLORADO              PEPPERDINE
# 8837   23-Jan-18                DUKE             WAKE_FOREST
#
#        away_points_pred  away_points
# 10340                92         92.0
# 8218                 91         91.0
# 2582                 89         89.0
# 6073                 89         89.0
# 838                  89         89.0
# 8508                 88         88.0
# 9689                 88         88.0
# 8126                 88         88.0
# 3569                 87         87.0
# 13123                87         87.0
# 14570                86         86.0
# 7756                 86         86.0
# 12027                86         86.0
# 3526                 85         85.0
# 8106                 85         85.0
# 8087                 85         85.0
# 9881                 84         84.0
# 8629                 84         84.0
# 5951                 84         84.0
# 8837                 84         84.0

# %% [markdown]
# #### Margin plot

# %% [markdown]
# a = (ggplot(game, aes(x= "margin", y="pred_margin",fill='mcheck')) +
#     geom_point() + labs(title="Margin vs Predicted Margin"))
# a + scale_x_continuous(limits = (0, 100)) +scale_y_continuous(limits = (0, 60)) +theme_bw()

# %% [markdown]
# ### Actual vs. Predicted Scores Box Plot:

# %% [markdown]
# #### Home:

# %%
a = (ggplot(game, aes(x= "home_Actual_vs_Predicted_scores_Margin", color="home_Actual_vs_Predicted_scores_Margin",fill="home_Actual_vs_Predicted_scores_Margin")) + 
    geom_bar() + labs(title="Home points vs Home Points Predicted",fill="Actual vs Predicted Margin Range",color="Actual vs Predicted Margin Range"))

a = a + theme(axis_text_x=element_text(rotation=90, hjust=1))
a
# Out:
# <ggplot: (8752309051712)>

# %%
ggsave(plot=a, filename='Bar Away Actual vs. Predicted Points.png', dpi=312,height=7, width=5, units = 'in')

# %% [markdown]
# #### Away

# %%
a = (ggplot(game, aes(x= "away_Actual_vs_Predicted_scores_Margin", color="away_Actual_vs_Predicted_scores_Margin",fill="away_Actual_vs_Predicted_scores_Margin")) + 
    geom_bar() + labs(title="Away points vs Away Points Predicted",fill="Actual vs Predicted Margin Range",color="Actual vs Predicted Margin Range"))

a = a + theme(axis_text_x=element_text(rotation=90, hjust=1))
a
# Out:
# <ggplot: (-9223363300253005631)>

# %%
game.to_csv(r'~/jupyter/capstone_Group10/data/gamedataXGBoostgridpredictionsallpca-analysis.csv', index = False)#saving cleaned data to csv for inspection
